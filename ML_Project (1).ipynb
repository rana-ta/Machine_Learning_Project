# %% [markdown]
# #  Predicting Movie Genre Popularity from Popular Reviews:
# In this project, we are going to use machine learning models to predict Letterboxd ratings of a movie genre particular.

# %% [markdown]
# # 1. Data Understanding

# %% [markdown]
# ###Dataset
# The Dataset used in this project is the *Letterboxd All Movie Data dataset*, which is available on Hugging Face.
#
# With over 800,000 movies, this dataset provides huge and diverse data, improving the reliability of training machine learning models across different genres, time periods, and audience demographics.
#
# The inclusion of both structured metadata (e.g., genres, release year) and unstructured text (reviews) allows us to capture both statistical patterns and audience sentiment, which is crucial for understanding long-term genre trends.

# %% [markdown]
# ### Importing Needed packages

# %%
from datasets import load_dataset
import pandas as pd
import ast
import re

# %% [markdown]
# ### Load the dataset

# %%
train_dataset = load_dataset("pkchwy/letterboxd-all-movie-data", split="train")

#Convert to a pandas Dataframe
df = pd.DataFrame(train_dataset)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# full_dump.jsonl:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/847209 [00:00<?, ? examples/s]

# %% [markdown]
# ### Preview the Dataset

# %%
#Displaying the First 5 Rows of the Dataset
df.head()
# Out:
#                                           url          title  year  \
# 0   https://letterboxd.com/film/come-and-see/   Come and See  1985
# 1  https://letterboxd.com/film/seven-samurai/  Seven Samurai  1954
# 2   https://letterboxd.com/film/high-and-low/   High and Low  1963
# 3       https://letterboxd.com/film/harakiri/       Harakiri  1962
# 4   https://letterboxd.com/film/12-angry-men/   12 Angry Men  1957
#
#             directors                             genres  \
# 0       [Elem Klimov]                       [War, Drama]
# 1    [Akira Kurosawa]                    [Action, Drama]
# 2    [Akira Kurosawa]  [Mystery, Thriller, Crime, Drama]
# 3  [Masaki Kobayashi]           [History, Drama, Action]
# 4      [Sidney Lumet]                            [Drama]
#
#                                                 cast  \
# 0  [Aleksei Kravchenko, Olga Mironova, Liubomiras...
# 1  [Toshirō Mifune, Takashi Shimura, Yoshio Inaba...
# 2  [Toshirō Mifune, Tatsuya Nakadai, Kyōko Kagawa...
# 3  [Tatsuya Nakadai, Akira Ishihama, Shima Iwashi...
# 4  [Martin Balsam, John Fiedler, Lee J. Cobb, E.G...
#
#                                             synopsis         rating  \
# 0  The invasion of a village in Byelorussia by Ge...  4.62 out of 5
# 1  A samurai answers a village's request for prot...  4.61 out of 5
# 2  In the midst of an attempt to take over his co...  4.60 out of 5
# 3  Down-on-his-luck veteran Tsugumo Hanshirō ente...  4.69 out of 5
# 4  The defense and the prosecution have rested an...  4.63 out of 5
#
#                                              reviews  \
# 0  [{'username': 'cameron fetter', 'review_text':...
# 1  [{'username': 'maria', 'review_text': 'too man...
# 2  [{'username': 'Karsten', 'review_text': 'every...
# 3  [{'username': 'Ciara', 'review_text': 'Why is ...
# 4  [{'username': 'amaya', 'review_text': '1. henr...
#
#                                           poster_url
# 0  https://a.ltrbxd.com/resized/film-poster/3/6/1...
# 1  https://a.ltrbxd.com/resized/film-poster/5/1/7...
# 2  https://a.ltrbxd.com/resized/film-poster/4/4/5...
# 3  https://a.ltrbxd.com/resized/film-poster/4/3/0...
# 4  https://a.ltrbxd.com/resized/film-poster/5/1/7...

# %%
# Get Information about the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847209 entries, 0 to 847208
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   url         847209 non-null  object
#  1   title       847209 non-null  object
#  2   year        770792 non-null  object
#  3   directors   732443 non-null  object
#  4   genres      638857 non-null  object
#  5   cast        595214 non-null  object
#  6   synopsis    727899 non-null  object
#  7   rating      108834 non-null  object
#  8   reviews     366600 non-null  object
#  9   poster_url  847209 non-null  object
# dtypes: object(10)
# memory usage: 64.6+ MB

# %%
# Check the Shape of the Dataset
df.shape
# Out:
# (847209, 10)

# %%
# Check Data Types
df.dtypes
# Out:
# url           object
# title         object
# year          object
# directors     object
# genres        object
# cast          object
# synopsis      object
# rating        object
# reviews       object
# poster_url    object
# dtype: object

# %% [markdown]
# # 2. Data Preparation

# %% [markdown]
# ###Missing Values

# %%
# Chech missing values
df.isnull().sum()
# Out:
# url                0
# title              0
# year           76417
# directors     114766
# genres        208352
# cast          251995
# synopsis      119310
# rating        738375
# reviews       480609
# poster_url         0
# dtype: int64

# %% [markdown]
# ### Dropping columns

# %% [markdown]
# We will keep the columns needed for this task, which are reviews, genres, year, and rating.

# %%
#Keeping only needed columns for the task
df = df[['reviews', 'genres', 'year','rating']]
df.head()
# Out:
#                                              reviews  \
# 0  [{'username': 'cameron fetter', 'review_text':...
# 1  [{'username': 'maria', 'review_text': 'too man...
# 2  [{'username': 'Karsten', 'review_text': 'every...
# 3  [{'username': 'Ciara', 'review_text': 'Why is ...
# 4  [{'username': 'amaya', 'review_text': '1. henr...
#
#                               genres  year         rating
# 0                       [War, Drama]  1985  4.62 out of 5
# 1                    [Action, Drama]  1954  4.61 out of 5
# 2  [Mystery, Thriller, Crime, Drama]  1963  4.60 out of 5
# 3           [History, Drama, Action]  1962  4.69 out of 5
# 4                            [Drama]  1957  4.63 out of 5

# %%
# Dropping rows with missing rows
df.dropna(subset=['reviews', 'genres', 'year','rating' ], inplace=True)

# %%
df.isnull().sum()
# Out:
# reviews    0
# genres     0
# year       0
# rating     0
# dtype: int64

# %% [markdown]
# ### Extracting the first Genre

# %% [markdown]
# For this task we will extract the first genre for each movie for a better and easier predection.

# %%
df["genre"] = df["genres"].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)

df = df.drop(columns=["genres"])
df["genre"].head()
# Out:
# 0        War
# 1     Action
# 2    Mystery
# 3    History
# 4      Drama
# Name: genre, dtype: object

# %% [markdown]
# ### Converting the Year column

# %% [markdown]
# We will convert the Year column to a numerical data type.

# %%
df['Year'] = df['year'].str.extract(r'(\d+)').astype(int)

# %% [markdown]
# ### Converting the Rating Column

# %% [markdown]
# We will conver the Rating column text from ("4.61 out of 5") to float.

# %%
df['rating'] = df['rating'].apply(lambda x: float(re.findall(r"[\d\.]+", x)[0]) if isinstance(x, str)else x)
df['rating'].head()
# Out:
# 0    4.62
# 1    4.61
# 2    4.60
# 3    4.69
# 4    4.63
# Name: rating, dtype: float64

# %% [markdown]
# ### Extract Review text

# %% [markdown]
# Each movie contain multiple reviews. We will make each review on its own row, while keeping the same genre, year, and rating for that movie.

# %%
expanded_rows = []
for _, row in df.iterrows():
  if isinstance (row["reviews"], list):
    for review in row["reviews"]:
      expanded_rows.append({
          "review_text": review.get("review_text", ""),
          "genre": row ["genre"],
          "year": row ["year"],
          "rating": row ["rating"],
      })
#Conver expanded list into a new Dataframe
reviews_df = pd.DataFrame(expanded_rows)

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk

nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = str(text).lower()  # lowercase
    text = re.sub(r'[^a-z\s]', '', text)  # remove non-letters
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return " ".join(words)

# Apply cleaning
reviews_df["cleaned_review"] = reviews_df["review_text"].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# ### Preview & Save the Cleaned Dataset

# %%
reviews_df.head(10)
# Out:
#                                          review_text genre  year  rating  \
# 0  as soon as this film ended i went online and e...   War  1985    4.62
# 1  Come and See is a film I find almost impossibl...   War  1985    4.62
# 2                         What a horrible nightmare!   War  1985    4.62
# 3  (guy who's still buzzing from Spider-Man: Acro...   War  1985    4.62
# 4  apparently elem klimov wanted to name this fil...   War  1985    4.62
# 5  Francois Truffaut once said that it is impossi...   War  1985    4.62
# 6  this makes other WWII movieslook like a ride a...   War  1985    4.62
# 7   Playing this at grandma’s bingo party next week.   War  1985    4.62
# 8  100%, no doubt in my mind, this is the best fi...   War  1985    4.62
# 9  An apocalyptic nightmare of pure brutalizing e...   War  1985    4.62
#
#                                       cleaned_review
# 0  soon film ended went online enlisted u army ch...
# 1  come see film find almost impossible review de...
# 2                                 horrible nightmare
# 3  guy who still buzzing spiderman across spiderv...
# 4  apparently elem klimov wanted name filmkill hi...
# 5  francois truffaut said impossible make truly a...
# 6        make wwii movieslook like ride disney world
# 7              playing grandma bingo party next week
# 8  doubt mind best film ever made cannot believe ...
# 9  apocalyptic nightmare pure brutalizing evil sh...

# %%
reviews_df.to_csv("lettedboxed_clean_dataset.csv", index=False, encoding="utf-8")

# %% [markdown]
# # Text Vectorization(TF-IDF)

# %% [markdown]
# 1.Use TF-IDF (Term Frequency–Inverse Document Frequency) to transform the cleaned_review column into numeric vectors.
#
# 2.Limit the number of features using max_features=5000 to maintain computational efficiency.
#
# 3.Store the vectorized output as X_text.
#
# 4.Convert the TF-IDF matrix into a DataFrame (X_text_df), where each column represents a unique term and each row represents a review.

# %%
import pandas as pd

df = pd.read_csv("lettedboxed_clean_dataset.csv")
print(df.columns)
# Out:
# Index(['review_text', 'genre', 'year', 'rating', 'cleaned_review'], dtype='object')

# %%
# تجاهل تحذيرات debugger وفrozen modules
# %env PYDEVD_DISABLE_FILE_VALIDATION=1
import sys
sys._xoptions["frozen_modules"] = "off"
# Out:
# env: PYDEVD_DISABLE_FILE_VALIDATION=1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("lettedboxed_clean_dataset.csv")

# %%
# Apply TF-IDF vectorization
tfidf = TfidfVectorizer(max_features=5000, stop_words='english')
X_text = tfidf.fit_transform(df['cleaned_review'].astype(str))

print("Shape of TF-IDF matrix:", X_text.shape)
# Out:
# Shape of TF-IDF matrix: (938388, 5000)
